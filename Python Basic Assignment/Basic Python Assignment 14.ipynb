# %% [raw]
# 1. What does RGBA stand for?
# Ans : R; Red, G: Green, B: Blue, A: Alpha

# %% [raw]
# 2. From the Pillow module, how do you get the RGBA value of any images?

# %%
from PIL import ImageColor
ImageColor.getcolor('pink',"RGBA")
# Out:
# (255, 192, 203, 255)

# %% [raw]
# 3. What is a box tuple, and how does it work?
# Ans : Box Tuple is tuple of four integer co-ordinates that specifies rectangular region in image
# boxtuple(x,y,b, h)
#
# x: The x-coordinate of the leftmost edge of the box.
#
# y: The y-coordinate of the top edge of the box.
#
# b: The x-coordinate of one pixel to the right of the rightmost edge of the box. This integer must be greater than the left integer.
#
# h The y-coordinate of one pixel lower than the bottom edge of the box. This integer must be greater than the top integer.

# %% [raw]
# 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %%
from PIL import Image
image = Image.open('akhilesh.jpg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225 at 0x1D5BD59E470>

# %%
width, height = image.size

# %%
width
# Out:
# 225

# %%
height
# Out:
# 225

# %% [raw]
# 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?
# Ans-
#
# croppedIm = catIm.crop((335, 345, 565, 560))
# croppedIm.save('cropped.png')

# %% [raw]
# 6. After making changes to an Image object, how could you save it as an image file?
# Image.save("img.jpg')

# %% [raw]
# 7. What module contains Pillow’s shape-drawing code?
# from PIL import ImageDraw

# %% [raw]
# 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?
# ANS-
# from PIL import ImageDraw

# %%
from PIL import ImageDraw

draw = ImageDraw.Draw(image)
draw.rectangle(xy=(50,50,50,50),fill = (1,124,2), outline = (255, 255, 255),width = 5)
image.show()
